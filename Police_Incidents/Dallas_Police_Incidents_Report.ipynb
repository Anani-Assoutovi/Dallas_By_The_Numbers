# %% [markdown]
# # Dallas Incidents Police Reports

# %% [markdown]
# This dataset contains detailed information on police incidents, including time, location, crime types, and demographic. It has 86 columns with 1347410 rows -- it is a medium size data sample, so predictive modeling results will be detailed.

# %% [markdown]
# Given the nature of this dataset, we can perform **Predictive Pnalysis Porkflow** to cover:
# * **Data Cleaning & Features Engineering**
# * **Geo-Coordinate extraction**
# * **Label Encoding & Time Features**
# * **Crime Type Forecasting** using classification
# * **Risk Modeling** using HeatMap (I considered KDE and Spatial Clustering but they're not as efficient).

# %% [markdown]
# First, we want to processed the data and create a modeling dataset with the following features:
# * **Latitude & Longitude:** Spatial coordinates
# * **Month, DayOfWeek, Hour:** time-based feature
# * **IncidentCategory:** encoded crime type

# %%
import streamlit as st
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Download the csv from the source first.
df = pd.read_csv('https://www.dallasopendata.com/Public-Safety/Police-Incidents/qv6i-rri7/about_data')

# We grab the first couple of observations for obervation purposes.
df.head()
# Out:
# /var/folders/9n/mqxgz_yj67j4r6yk7yp0y0kh0000gn/T/ipykernel_42914/3244680668.py:2: DtypeWarning: Columns (3,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Police_Incidents_20250505.csv')
#         Incident Number w/year  Year of Incident Service Number ID Watch  \
# 818926             122960-2023              2023    122960-2023-01     2
# 304888             166799-2018              2018    166799-2018-01     2
# 1243428            025871-2022              2022    025871-2022-01     3
# 708232             048018-2020              2020    048018-2020-01     1
# 287187             162873-2020              2020    162873-2020-02     3
#
#                  Call (911) Problem  \
# 818926   58 - ROUTINE INVESTIGATION
# 304888      12R - RESIDENTIAL ALARM
# 1243428                  09V - UUMV
# 708232   58 - ROUTINE INVESTIGATION
# 287187                40/01 - OTHER
#
#                                           Type of Incident  \
# 818926                         CRIMINAL TRESPASS AFFIDAVIT
# 304888                  ALARM INCIDENT REPORT (NO OFFENSE)
# 1243428         UNAUTHORIZED USE OF MOTOR VEH - AUTOMOBILE
# 708232   THEFT OF SERVICE > OR EQUAL $2,500 <$30K PC31....
# 287187               CRIM MISCHIEF >OR EQUAL $750 < $2,500
#
#                      Type  Location Type of Property     Incident Address  \
# 818926                        Other              NaN  2029 S BUCKNER BLVD
# 304888   Apartment Complex/Building              NaN    4412 MCKINNEY AVE
# 1243428          Parking (Business)    Motor Vehicle    1601 MCKINNEY AVE
# 708232           Parking (Business)    Motor Vehicle       2992 FOREST LN
# 287187   Apartment Complex/Building              NaN      11333 AMANDA LN
#
#         Apartment Number  ...  NIBRS Code  NIBRS Group      NIBRS Type  \
# 818926               NaN  ...         999            C  999 - No Coded
# 304888                13  ...         999            C  999 - No Coded
# 1243428              NaN  ...         240            A           Coded
# 708232               NaN  ...         26A            A           Coded
# 287187              1004  ...         290            A           Coded
#
#                          Update Date  X Coordinate   Y Cordinate Zip Code  \
# 818926   2023-07-30 14:12:47.0000000  2.526947e+06  6.959796e+06  75217.0
# 304888   2018-07-30 15:04:23.0000000  2.494047e+06  6.985400e+06  75205.0
# 1243428  2024-12-18 11:42:37.0000000  2.489361e+06  6.973666e+06  75202.0
# 708232   2020-07-11 01:09:15.0000000  2.466652e+06  7.017502e+06  75234.0
# 287187   2022-10-18 10:49:18.0000000  2.524166e+06  7.006383e+06  75238.0
#
#            City  State                                          Location1
# 818926   DALLAS     TX  2029 S BUCKNER BLVD\nDALLAS, TX 75217\n(32.747...
# 304888   DALLAS     TX  4412 MCKINNEY AVE\nDALLAS, TX 75205\n(32.81988...
# 1243428  DALLAS     TX  1601 MCKINNEY AVE\nDALLAS, TX 75202\n(32.78753...
# 708232   DALLAS     TX  2992 FOREST LN\nDALLAS, TX 75234\n(32.90900301...
# 287187   DALLAS     TX  11333 AMANDA LN\nDALLAS, TX 75238\n(32.8758880...
#
# [5 rows x 86 columns]

# %% [markdown]
# Now, we can:
# 1) split the data into training and test sets
# 2) Train a classification model to predict **IncidentCategory** (crime type)
# 3) Evaluate performance
# 4) Generate a heatmap using 'Follium' modeling

# %%
import re
from sklearn.preprocessing import LabelEncoder
from datetime import datetime

# %%
# We want to copy the original dataset for processing
df = df.copy()

# We need to extract coordinates from 'Location1' as Latitude and Longitude
def extract_coords(location):
    match = re.search(r'\(([-\d.]+),\s*([-\d.]+)\)', str(location))
    if match:
        return float(match.group(1)), float(match.group(2))
    return None, None

# We apply the extracted df
df[['Latitude', 'Longitude']] = df['Location1'].apply(lambda x: pd.Series(extract_coords(x)))

df.head()
# Out:
#   Incident Number w/year  Year of Incident Service Number ID  Watch  \
# 0            227907-2015              2015    227907-2015-01      2
# 1            238085-2019              2019    238085-2019-01      3
# 2            126427-2021              2021    126427-2021-01      3
# 3            249485-2016              2016    249485-2016-01      1
# 4            100969-2022              2022    100969-2022-01      1
#
#               Call (911) Problem                        Type of Incident  \
# 0     58 - ROUTINE INVESTIGATION        ILLEGAL DUMPING 1000 LBS OR MORE
# 1                  19 - SHOOTING            ASSAULT (AGG) -DEADLY WEAPON
# 2  41/20 - ROBBERY - IN PROGRESS               ROBBERY OF BUSINESS (AGG)
# 3     6X - MAJOR DIST (VIOLENCE)  CRIM MISCHIEF >OR EQUAL $100 BUT <$750
# 4    6XA - MAJOR DIST  AMBULANCE             ASSAULT -BODILY INJURY ONLY
#
#                        Type  Location Type of Property     Incident Address  \
# 0         Outdoor Area Public/Private              NaN  3000 S LEDBETTER DR
# 1        Condominium/Townhome Parking              NaN      2525 PLAYERS CT
# 2                           Rest Area              NaN       3938 S POLK ST
# 3  Single Family Residence - Occupied              NaN        3134 UTAH AVE
# 4               Apartment Parking Lot              NaN   12708 SCHROEDER RD
#
#   Apartment Number  ...  NIBRS Type                  Update Date  \
# 0              NaN  ...         NaN  2015-10-09 14:57:32.0000000
# 1             1402  ...       Coded  2023-06-26 10:09:29.0000000
# 2              NaN  ...       Coded  2022-03-07 14:30:48.0000000
# 3              NaN  ...         NaN  2016-10-24 09:35:09.0000000
# 4              NaN  ...       Coded  2022-06-21 15:48:09.0000000
#
#    X Coordinate   Y Cordinate Zip Code    City State  \
# 0  2.453378e+06  6.944537e+06  75211.0  DALLAS    TX
# 1  2.469747e+06  7.047277e+06  75287.0  DALLAS    TX
# 2  2.479206e+06  6.940459e+06  75224.0  DALLAS    TX
# 3  2.488556e+06  6.944035e+06  75216.0  DALLAS    TX
# 4  2.502145e+06  7.022398e+06  75243.0  DALLAS    TX
#
#                                            Location1   Latitude  Longitude
# 0  3000 S LEDBETTER DR\nDALLAS, TX 75211\n(32.707...  32.707467 -96.925177
# 1  2525 PLAYERS CT\nDALLAS, TX 75287\n(32.9913260...  32.991326 -96.866043
# 2  3938 S POLK ST\nDALLAS, TX 75224\n(32.69675, -...  32.696750 -96.839985
# 3  3134 UTAH AVE\nDALLAS, TX 75216\n(32.706170014...  32.706170 -96.809269
# 4  12708 SCHROEDER RD\nDALLAS, TX 75243\n(32.9203...  32.920389 -96.760836
#
# [5 rows x 88 columns]

# %%
# Now, we want to convert 'Date1 of Occurrence' to datetime and extract features
df['Date1 of Occurrence'] = pd.to_datetime(df['Date1 of Occurrence'])
df['Month'] = df['Date1 of Occurrence'].dt.month
df['DayOfWeek'] = df['Date1 of Occurrence'].dt.dayofweek
df['Hour'] = pd.to_datetime(df['Time1 of Occurrence'], format='%H:%M').dt.hour

df.head()
# Out:
#   Incident Number w/year  Year of Incident Service Number ID  Watch  \
# 0            227907-2015              2015    227907-2015-01      2
# 1            238085-2019              2019    238085-2019-01      3
# 2            126427-2021              2021    126427-2021-01      3
# 3            249485-2016              2016    249485-2016-01      1
# 4            100969-2022              2022    100969-2022-01      1
#
#               Call (911) Problem                        Type of Incident  \
# 0     58 - ROUTINE INVESTIGATION        ILLEGAL DUMPING 1000 LBS OR MORE
# 1                  19 - SHOOTING            ASSAULT (AGG) -DEADLY WEAPON
# 2  41/20 - ROBBERY - IN PROGRESS               ROBBERY OF BUSINESS (AGG)
# 3     6X - MAJOR DIST (VIOLENCE)  CRIM MISCHIEF >OR EQUAL $100 BUT <$750
# 4    6XA - MAJOR DIST  AMBULANCE             ASSAULT -BODILY INJURY ONLY
#
#                        Type  Location Type of Property     Incident Address  \
# 0         Outdoor Area Public/Private              NaN  3000 S LEDBETTER DR
# 1        Condominium/Townhome Parking              NaN      2525 PLAYERS CT
# 2                           Rest Area              NaN       3938 S POLK ST
# 3  Single Family Residence - Occupied              NaN        3134 UTAH AVE
# 4               Apartment Parking Lot              NaN   12708 SCHROEDER RD
#
#   Apartment Number  ...   Y Cordinate  Zip Code    City  State  \
# 0              NaN  ...  6.944537e+06   75211.0  DALLAS     TX
# 1             1402  ...  7.047277e+06   75287.0  DALLAS     TX
# 2              NaN  ...  6.940459e+06   75224.0  DALLAS     TX
# 3              NaN  ...  6.944035e+06   75216.0  DALLAS     TX
# 4              NaN  ...  7.022398e+06   75243.0  DALLAS     TX
#
#                                            Location1   Latitude  Longitude  \
# 0  3000 S LEDBETTER DR\nDALLAS, TX 75211\n(32.707...  32.707467 -96.925177
# 1  2525 PLAYERS CT\nDALLAS, TX 75287\n(32.9913260...  32.991326 -96.866043
# 2  3938 S POLK ST\nDALLAS, TX 75224\n(32.69675, -...  32.696750 -96.839985
# 3  3134 UTAH AVE\nDALLAS, TX 75216\n(32.706170014...  32.706170 -96.809269
# 4  12708 SCHROEDER RD\nDALLAS, TX 75243\n(32.9203...  32.920389 -96.760836
#
#   Month  DayOfWeek Hour
# 0    10          3    5
# 1    11          0   19
# 2     7          4   16
# 3    10          0    0
# 4     6          0    6
#
# [5 rows x 91 columns]

# %%
# Next, we want to encode categorical columns
cat_columns = LabelEncoder()
df['IncidentCategory'] = cat_columns.fit_transform(df['Type of Incident'].astype(str))

df['IncidentCategory'].head()
# Out:
# 0    135
# 1     12
# 2    198
# 3     54
# 4     16
# Name: IncidentCategory, dtype: int64

# %%
# Now, we drop rows with missing key features
df = df.dropna(subset=['Latitude', 'Longitude', 'Month', 'DayOfWeek', 'Hour', 'IncidentCategory'])

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7942 entries, 0 to 7999
# Data columns (total 92 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Incident Number w/year                     7942 non-null   object
#  1   Year of Incident                           7942 non-null   int64
#  2   Service Number ID                          7942 non-null   object
#  3   Watch                                      7942 non-null   int64
#  4   Call (911) Problem                         7311 non-null   object
#  5   Type of Incident                           7942 non-null   object
#  6   Type  Location                             7930 non-null   object
#  7   Type of Property                           1638 non-null   object
#  8   Incident Address                           7942 non-null   object
#  9   Apartment Number                           1800 non-null   object
#  10  Reporting Area                             7936 non-null   float64
#  11  Beat                                       7939 non-null   float64
#  12  Division                                   7939 non-null   object
#  13  Sector                                     7940 non-null   float64
#  14  Council District                           7928 non-null   object
#  15  Target Area Action Grids                   2841 non-null   object
#  16  Community                                  827 non-null    object
#  17  Date1 of Occurrence                        7942 non-null   datetime64[ns]
#  18  Year1 of Occurrence                        7942 non-null   int64
#  19  Month1 of Occurence                        7942 non-null   object
#  20  Day1 of the Week                           7942 non-null   object
#  21  Time1 of Occurrence                        7942 non-null   object
#  22  Day1 of the Year                           7942 non-null   int64
#  23  Date2 of Occurrence                        7942 non-null   object
#  24  Year2 of Occurrence                        7942 non-null   float64
#  25  Month2 of Occurence                        7942 non-null   object
#  26  Day2 of the Week                           7942 non-null   object
#  27  Time2 of Occurrence                        7942 non-null   object
#  28  Day2 of the Year                           7942 non-null   float64
#  29  Date of Report                             7942 non-null   object
#  30  Date incident created                      7942 non-null   object
#  31  Offense Entered Year                       7942 non-null   int64
#  32  Offense Entered Month                      7942 non-null   object
#  33  Offense Entered Day of the Week            7942 non-null   object
#  34  Offense Entered Time                       7942 non-null   object
#  35  Offense Entered  Date/Time                 7942 non-null   int64
#  36  CFS Number                                 7311 non-null   object
#  37  Call Received Date Time                    7311 non-null   object
#  38  Call Date Time                             7311 non-null   object
#  39  Call Cleared Date Time                     7307 non-null   object
#  40  Call Dispatch Date Time                    7309 non-null   object
#  41  Special Report (Pre-RMS)                   34 non-null     object
#  42  Person Involvement Type                    7632 non-null   object
#  43  Victim Type                                7589 non-null   object
#  44  Victim Race                                5045 non-null   object
#  45  Victim Ethnicity                           5034 non-null   object
#  46  Victim Gender                              5028 non-null   object
#  47  Responding Officer #1  Badge No            7298 non-null   object
#  48  Responding Officer #1  Name                7296 non-null   object
#  49  Responding Officer #2 Badge No             2525 non-null   object
#  50  Responding Officer #2  Name                2525 non-null   object
#  51  Reporting Officer Badge No                 7306 non-null   object
#  52  Assisting Officer Badge No                 6067 non-null   object
#  53  Reviewing Officer Badge No                 7931 non-null   object
#  54  Element Number Assigned                    7311 non-null   object
#  55  Investigating Unit 1                       5883 non-null   object
#  56  Investigating Unit 2                       5883 non-null   object
#  57  Offense Status                             7881 non-null   object
#  58  UCR Disposition                            7881 non-null   object
#  59  Modus Operandi (MO)                        7180 non-null   object
#  60  Family Offense                             7311 non-null   object
#  61  Hate Crime                                 4 non-null      object
#  62  Hate Crime Description                     147 non-null    object
#  63  Weapon Used                                2481 non-null   object
#  64  Gang Related Offense                       2912 non-null   object
#  65  Drug Related Istevencident                 7314 non-null   object
#  66  RMS Code                                   7942 non-null   object
#  67  Criminal Justice Information Service Code  7935 non-null   float64
#  68  Penal Code                                 7935 non-null   object
#  69  UCR Offense Name                           2373 non-null   object
#  70  UCR Offense Description                    2373 non-null   object
#  71   UCR Code                                  2373 non-null   float64
#  72  Offense Type                               2373 non-null   object
#  73  NIBRS Crime                                6427 non-null   object
#  74  NIBRS Crime Category                       6427 non-null   object
#  75  NIBRS Crime Against                        6427 non-null   object
#  76  NIBRS Code                                 6427 non-null   object
#  77  NIBRS Group                                6427 non-null   object
#  78  NIBRS Type                                 6439 non-null   object
#  79  Update Date                                7942 non-null   object
#  80  X Coordinate                               7940 non-null   float64
#  81  Y Cordinate                                7940 non-null   float64
#  82  Zip Code                                   7937 non-null   float64
#  83  City                                       7934 non-null   object
#  84  State                                      7805 non-null   object
#  85  Location1                                  7942 non-null   object
#  86  Latitude                                   7942 non-null   float64
#  87  Longitude                                  7942 non-null   float64
#  88  Month                                      7942 non-null   int32
#  89  DayOfWeek                                  7942 non-null   int32
#  90  Hour                                       7942 non-null   int32
#  91  IncidentCategory                           7942 non-null   int64
# dtypes: datetime64[ns](1), float64(12), int32(3), int64(7), object(69)
# memory usage: 5.5+ MB
#   Incident Number w/year  Year of Incident Service Number ID  Watch  \
# 0            227907-2015              2015    227907-2015-01      2
# 1            238085-2019              2019    238085-2019-01      3
# 2            126427-2021              2021    126427-2021-01      3
# 3            249485-2016              2016    249485-2016-01      1
# 4            100969-2022              2022    100969-2022-01      1
#
#               Call (911) Problem                        Type of Incident  \
# 0     58 - ROUTINE INVESTIGATION        ILLEGAL DUMPING 1000 LBS OR MORE
# 1                  19 - SHOOTING            ASSAULT (AGG) -DEADLY WEAPON
# 2  41/20 - ROBBERY - IN PROGRESS               ROBBERY OF BUSINESS (AGG)
# 3     6X - MAJOR DIST (VIOLENCE)  CRIM MISCHIEF >OR EQUAL $100 BUT <$750
# 4    6XA - MAJOR DIST  AMBULANCE             ASSAULT -BODILY INJURY ONLY
#
#                        Type  Location Type of Property     Incident Address  \
# 0         Outdoor Area Public/Private              NaN  3000 S LEDBETTER DR
# 1        Condominium/Townhome Parking              NaN      2525 PLAYERS CT
# 2                           Rest Area              NaN       3938 S POLK ST
# 3  Single Family Residence - Occupied              NaN        3134 UTAH AVE
# 4               Apartment Parking Lot              NaN   12708 SCHROEDER RD
#
#   Apartment Number  ...  Zip Code    City State  \
# 0              NaN  ...   75211.0  DALLAS    TX
# 1             1402  ...   75287.0  DALLAS    TX
# 2              NaN  ...   75224.0  DALLAS    TX
# 3              NaN  ...   75216.0  DALLAS    TX
# 4              NaN  ...   75243.0  DALLAS    TX
#
#                                            Location1   Latitude  Longitude  \
# 0  3000 S LEDBETTER DR\nDALLAS, TX 75211\n(32.707...  32.707467 -96.925177
# 1  2525 PLAYERS CT\nDALLAS, TX 75287\n(32.9913260...  32.991326 -96.866043
# 2  3938 S POLK ST\nDALLAS, TX 75224\n(32.69675, -...  32.696750 -96.839985
# 3  3134 UTAH AVE\nDALLAS, TX 75216\n(32.706170014...  32.706170 -96.809269
# 4  12708 SCHROEDER RD\nDALLAS, TX 75243\n(32.9203...  32.920389 -96.760836
#
#   Month DayOfWeek  Hour IncidentCategory
# 0    10         3     5              135
# 1    11         0    19               12
# 2     7         4    16              198
# 3    10         0     0               54
# 4     6         0     6               16
#
# [5 rows x 92 columns]

# %% [markdown]
# Next, we want to proceed with the **Crime Risk Modeling using Follium** to generate a heatmap of incident concentration.

# %%
#First, we import the libraries
import folium
from folium.plugins import HeatMap

# %%
# Now, we are creating a folium map centered around the average location
center_lat = df['Latitude'].mean()
center_lon = df['Longitude'].mean()
map_heatmap = folium.Map(location=[center_lat, center_lon], zoom_start=12)

# Here, we are preparing the data for heatmap
heat_data = df[['Latitude', 'Longitude']].values.tolist()

# We are adding a heatmap layer
HeatMap(heat_data).add_to(map_heatmap)

# We are saving our result heatmap to HTML
output_path = "Police_Incidents_heatmap.html"
map_heatmap.save(output_path)

output_path

display(map_heatmap)
## Please check the current directory for the .html file to view the interactive results.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8354f63050237c965e2c116223248329 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8354f63050237c965e2c116223248329&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8354f63050237c965e2c116223248329 = L.map(
#                 &quot;map_8354f63050237c965e2c116223248329&quot;,
#                 {
#                     center: [32.8005579622993, -96.79020949470721],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36aa42eb80cb1c53d82a10dd9a337494 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8354f63050237c965e2c116223248329);
#
#
#             var heat_map_2616f989108e33592f11858491508085 = L.heatLayer(
#                 [[32.707467469, -96.925177336], [32.991326006, -96.866042985], [32.69675, -96.839985], [32.706170014, -96.809269002], [32.920389, -96.760836], [32.782243999, -96.682019977], [32.874106012, -96.882604033], [32.779098983, -96.797710022], [32.873872, -96.867892], [32.742044014, -96.68019004], [32.701862009, -96.761538003], [32.787159985, -96.738069009], [32.78969, -96.76536], [32.71238, -96.77441], [32.780418001, -96.788652035], [32.65427, -96.8499], [32.874106012, -96.882604033], [32.890027018, -96.882323994], [32.73310405, -96.809040314], [32.774514, -96.770512], [32.78453, -96.90003], [32.868333018, -96.773454974], [32.742024987, -96.833389018], [32.741916, -96.676241], [32.763170014, -96.848898976], [32.922433006, -96.756710027], [32.89093, -96.89274], [32.87785201, -96.866656959], [32.811064, -96.806285967], [32.733163011, -96.865137991], [32.87870309, -96.729251372], [32.813284994, -96.688259969], [32.8531, -96.65432], [32.782339008, -96.715314992], [32.786464, -96.786302], [32.798918999, -96.687325973], [32.769002017, -96.739742959], [32.778097011, -96.920277], [32.763381, -96.680603], [32.785379666, -96.874481883], [32.828888997, -96.826179995], [32.999640015, -96.797967011], [32.754156, -96.670336], [32.77500698, -96.815528021], [32.86277699, -96.752535001], [32.882808984, -96.896731982], [32.738107998, -96.895557007], [32.811729984, -96.782337025], [32.762624981, -96.897272028], [32.80995302, -96.672999038], [32.851550017, -96.817943015], [32.838230547, -96.843826532], [32.684826, -96.619155033], [32.748250981, -96.679469029], [32.876841991, -96.732546006], [32.78547, -96.78216],
#          266       0.00      0.00      0.00         1
#          267       0.00      0.00      0.00         2
#          269       0.00      0.00      0.00         4
#          270       0.00      0.00      0.00        14
#          272       0.00      0.00      0.00         0
#          273       0.00      0.00      0.00         1
#          274       0.00      0.00      0.00         0
#          275       0.00      0.00      0.00         1
#          276       0.00      0.00      0.00        22
#          277       0.00      0.00      0.00         2
#          279       0.00      0.00      0.00         1
#          280       0.00      0.00      0.00         1
#          281       0.00      0.00      0.00         4
#          284       0.00      0.00      0.00         5
#          286       0.00      0.00      0.00         2
#          287       0.00      0.00      0.00         0
#          288       0.00      0.00      0.00         9
#          289       0.00      0.00      0.00         1
#          291       0.00      0.00      0.00         4
#          294       0.00      0.00      0.00        24
#          295       0.00      0.00      0.00         5
#          296       0.00      0.00      0.00         1
#          297       0.00      0.00      0.00         7
#          298       0.00      0.00      0.00         0
#          301       0.00      0.00      0.00         1
#          302       0.00      0.00      0.00         1
#          303       0.00      0.00      0.00         1
#          304       0.00      0.00      0.00         1
#          306       0.00      0.00      0.00         0
#          307       0.00      0.00      0.00         0
#          308       0.00      0.00      0.00         0
#          310       0.00      0.00      0.00         0
#          311       0.00      0.00      0.00         3
#          312       0.00      0.00      0.00         5
#          313       0.00      0.00      0.00         5
#          315       0.00      0.00      0.00         2
#          316       0.00      0.00      0.00         2
#          317       0.00      0.00      0.00         2
#          318       0.00      0.00      0.00         6
#          319       0.00      0.00      0.00         4
#          320       0.00      0.00      0.00        24
#          322       0.00      0.00      0.00         1
#          323       0.00      0.00      0.00         1
#          324       0.00      0.00      0.00         2
#          325       0.00      0.00      0.00         3
#          327       0.04      0.03      0.03        36
#          328       0.00      0.00      0.00         0
#          329       0.00      0.00      0.00        13
#          330       0.10      0.21      0.14       235
#          331       0.00      0.00      0.00        16
#          332       0.00      0.00      0.00         5
#          333       0.05      0.05      0.05       111
#          336       0.00      0.00      0.00         9
#          337       0.00      0.00      0.00         6
#          338       0.00      0.00      0.00         0
#          339       0.00      0.00      0.00         2
#          340       0.00      0.00      0.00         1
#          342       0.00      0.00      0.00         5
#          343       0.00      0.00      0.00         5
#          344       0.00      0.00      0.00         1
#
#     accuracy                           0.07      2383
#    macro avg       0.01      0.01      0.01      2383
# weighted avg       0.04      0.07      0.05      2383
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import ExponentialSmoothing

df['IncidentMonth'] = pd.DatetimeIndex(df['Date1 of Occurrence']).to_period('M')
monthly_counts = df.groupby('IncidentMonth').size().rename('IncidentCount').to_timestamp()
monthly_counts = monthly_counts.dropna()

model = ExponentialSmoothing(monthly_counts, trend='additive', seasonal=None, initialization_method="estimated")
fit_model = model.fit()

forecast = fit_model.forecast(6)
print(monthly_counts)
print("Forecast:")
print(forecast)
# Out:
# IncidentMonth
# 2000-09-01     1
# 2006-05-01     1
# 2007-01-01     1
# 2013-01-01     1
# 2013-05-01     1
#               ..
# 2025-01-01    51
# 2025-02-01    62
# 2025-03-01    62
# 2025-04-01    57
# 2025-05-01     9
# Name: IncidentCount, Length: 142, dtype: int64
# Forecast:
# 142    34.347540
# 143    34.583746
# 144    34.819952
# 145    35.056158
# 146    35.292364
# 147    35.528571
# dtype: float64
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /opt/anaconda3/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
